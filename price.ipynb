# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sys                                               ## 파이썬 엔진에 대한 정보를 관리하는 모듈을 사용한다. 
from matplotlib import font_manager, rc                  ## 폰트를 관리하는 함수와 설정 함수를 사용한다. 

if sys.platform  == 'darwin':                             ## MAC OS의 이름을 확인한다.
    path = '.....'  
elif sys.platform == 'win32':                             ## Windows 이름을 확인한다.
    path = "font/malgun.ttf"
else:
    print('Unknown system... sorry~~~~') 
    
font_name = font_manager.FontProperties(fname=path).get_name()        ##  폰트가 있는지를 확인한다. 
rc('font', family=font_name)                                          ## 한글 폰트를 시각화 환경에 세팅한다. 
plt.rcParams['axes.unicode_minus'] = False

# %%
data = pd.read_excel('./data/price/평균매매가격_종합.xlsx', header=10)
data = data.drop(['Unnamed: 1', 'Unnamed: 2'], axis=1)
data = data.loc[[0,1,2]]
data.set_index('지 역' ,inplace=True)

# %%
data = data[['2019년 01월', '2019년 07월', '2020년 01월', '2020년 07월', '2021년 01월', '2021년 07월', '2022년 01월']]

# %%
colors = sns.color_palette('Blues',len(data.columns))

plt.rcParams['font.size'] = 15
plt.rcParams['figure.figsize'] = (10, 6)

fig, ax1 = plt.subplots()

ax1.bar(data.T.index, data.T['전국'], label='전국', color=colors)

ax1.plot(data.T.index, data.T['수도권'], label='수도권', linewidth=4, color ='darkgrey', marker='o', markersize=10)

ax1.plot(data.T.index, data.T['지방권'], label='지방권', linewidth=4, color ='orange', marker='o', markersize=10)

ax1.set_xlabel('연도')
ax1.set_ylabel('가격')
               
ax1.legend(loc='best')
plt.show()

# %%
data.T.index
# Out:
# Index(['2018년 01월', '2018년 07월', '2019년 01월', '2019년 07월', '2020년 01월',
#        '2020년 07월', '2021년 01월', '2021년 07월', '2022년 01월'],
#       dtype='object')
